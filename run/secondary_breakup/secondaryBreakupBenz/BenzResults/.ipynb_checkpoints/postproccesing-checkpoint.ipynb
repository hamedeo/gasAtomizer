# %%
import os
import glob
import sys
import vtk

import pandas as pd    
import numpy as np
import matplotlib.pyplot as plt
from vtk.util.numpy_support import vtk_to_numpy

# %%
#Include depicted data...
#Case 2 -------------------------- Diameter import
data_Wave= pd.read_csv("./Case_Liu/Wave_Case2.csv", header=None) # Wave_Case2.csv
data_TAB= pd.read_csv("./Case_Liu/TAB_Case2.csv", header=None) # TAB_Case2.csv
data_PDPA= pd.read_csv("./Case_Liu/PDPA_Case2.csv", header=None) # PDPA_Case2.csv

#Case 3 -------------------------- Diameter import
TAB_Case3= pd.read_csv("./Case_Liu/TAB_Case3.csv", header=None) # TAB_Case3.csv
KH_Case3= pd.read_csv("./Case_Liu/Wave_Case3.csv", header=None) # SMD_KH_Case3Experiment.csv
PDPA_Case3= pd.read_csv("./Case_Liu/PDPA_Case3.csv", header=None) # PDPA_Case3.csv

#Case 4 -------------------------- Single droplet breakup
data_C4_SingleD= pd.read_csv("./Case_Liu/Case_4_Single_D.csv", header=None) # Case_4_Single_D.csv
data_C4_SingleRe= pd.read_csv("./Case_Liu/Case4_Single_Re.csv", header=None) # Case4_Single_Re.csv

#Case 2 ------------------------ Trajectory import
TAB_Traject_Case2= pd.read_csv("./Case_Liu/Trajectories/Trajectory_TAB_Case2.csv", header=None) # Trajectory_TAB_Case2.csv
Wave_Traject_Case2= pd.read_csv("./Case_Liu/Trajectories/Trajectory_Wave_Case2.csv", header=None) # Trajectory_Wave_Case2.csv
Wave_st_Traject_Case2= pd.read_csv("./Case_Liu/Trajectories/Trajectory_Wave_Case2-standard.csv", header=None) # Trajectory_Wave_Case2.csv
Traject_Exp_Case2= pd.read_csv("./Case_Liu/Trajectories/Trajectory_Experiment_Case2.csv", header=None) # Trajectory_Experiment_Case2.csv

#Case 4 -------------------------- Trajectory import
TAB_Traject_Case4= pd.read_csv("./Case_Liu/Trajectories/TAB_Case4_amp0_2.csv", header=None) # TAB_Traject_Case4.csv
Wave_Traject_Case4= pd.read_csv("./Case_Liu/Trajectories/Trajectory_Wave_Case4.csv", header=None) # Trajectory_Wave_Case4.csv
Traject_Exp_Case4= pd.read_csv("./Case_Liu/Trajectories/Trajectory_Experiment_Case4.csv", header=None) # Trajectory_Experiment_Case4.csv

# %%
fdir = "./Case2/KH_sphereDrag/lagrangian/sprayCloud" # sprayCloud file of Case 3 TAB model to read vtp from VTK file 
#check if directory exists
if not os.path.exists(fdir):
    print('Error: Path does not exist:', fdir)
    sys.exit()

# %%
# create reader
reader = vtk.vtkXMLPolyDataReader() # a class that reads an XML-based VTK file format that contains polygonal data
# -------------------------------------------------------------------
points =[]
point_data=[]
point_d = []
point_d0 = [];
#loop over all vtp files
for fname in sorted(glob.glob(os.path.join(fdir, '*.vtp'))): # fdir in where vtp files stored 
    print('Reading:', fname)
    reader.SetFileName(fname)
    reader.Update()

    # print the arrays
    data = (reader.GetOutput())
    point_data.append(data.GetPointData())
    point_d.append(vtk_to_numpy((data.GetPointData()).GetArray('d')))
    point_d0.append(vtk_to_numpy((data.GetPointData()).GetArray('d0')))    
    points.append((vtk_to_numpy(data.GetPoints().GetData())))
# Out:
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3154.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3163.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3172.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3181.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3190.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3199.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3208.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3217.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3226.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3235.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3244.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3253.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3262.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3271.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3280.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3289.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3298.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3307.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3316.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3325.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3334.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3343.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3352.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3361.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3370.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3379.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3388.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3397.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3406.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3415.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3424.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3433.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3442.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3451.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3460.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3469.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3478.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3487.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3496.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3505.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3514.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3523.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3532.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3541.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3550.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3559.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3568.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3577.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3586.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3595.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3604.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3613.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3622.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3631.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3640.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3649.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3658.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3667.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3676.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3685.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3694.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3703.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3712.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3721.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3730.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3739.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3748.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3757.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3766.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3775.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3784.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3793.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3802.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3811.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3820.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3829.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3838.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3847.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3856.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3865.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3874.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3883.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3892.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3901.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3910.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3919.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3928.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3937.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3946.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3955.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3964.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3973.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3982.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_3991.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4000.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4009.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4018.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4027.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4036.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4045.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4054.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4063.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4072.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4081.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4090.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4099.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4108.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4117.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4126.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4135.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4144.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4153.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4162.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4171.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4180.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4189.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4198.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4207.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4216.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4225.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4234.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4243.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4252.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4261.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4270.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4279.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4288.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4297.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4306.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4315.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4324.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4333.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4342.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4351.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4360.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4369.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4378.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4387.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4396.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4405.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4414.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4423.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4432.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4441.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4450.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4459.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4468.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4477.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4486.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4495.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4504.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4513.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4522.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4531.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4540.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4549.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4558.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4567.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4576.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4585.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4594.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4603.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4612.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4621.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4630.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4639.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4648.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4657.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4666.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4675.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4684.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4693.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4702.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4711.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4720.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4729.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4738.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4747.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4756.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4765.vtp
# Reading: ./Case2/KH_sphereDrag/lagrangian/sprayCloud/sprayCloud_4774.vtp

# %%
d0 =[];
for i in range(0, len(points)):
    d0.append(np.array(point_d0[i]))
d0=np.concatenate(d0,axis=0)

# %%
px=[]
py=[]
pz=[]
for i in range(0, len(points)):
    px.append(np.array(points[i][:,0]))
    py.append(np.array(points[i][:,1]))
    pz.append(np.array(points[i][:,2]))

# %%
diameter =[]
Reyn =[]
diameter0=[]
for i in range(0, len(points)):
    diameter.append(np.array(point_d[i]))
#     Reyn.append(np.array(Re[i]))
    diameter0.append(np.array(d0[i]))

# %%
diameter_total = np.concatenate( diameter, axis=0 )
px_total = np.concatenate( px, axis=0 )
py_total = np.concatenate( py, axis=0 )
pz_total = np.concatenate( pz, axis=0 )

c = np.column_stack((py_total, pz_total,diameter_total))
c_sorted = c[np.argsort(c[:, 0])]

# %%
plt.plot(c_sorted[:,0]+0.00572,c_sorted[:,1], 'o')
plt.xlabel('Horizontal position of the droplets')
plt.ylabel('Vertical position of the droplets')
plt.title('All position data from the simulation sorted over the horizontal position')
plt.xlim(0,0.008)
# Out:
# (0.0, 0.008)

# %%
plt.plot(c_sorted[:,0],c_sorted[:,2])
plt.xlabel('Horizontal position of the droplets [m]')
plt.ylabel('Droplet diameter [m]')
plt.title('Droplet diameter over the horizontal penetration distance')
plt.xlim(-0.0072,0.0057625)
# Out:
# (-0.0072, 0.0057625)

# %%
# Computing the Sauter mean diameter for a specific amount of segments
d3 = pow(c_sorted[:,2],3)
sigma_d3 = sum(d3)
d2 = pow(c_sorted[:,2],2)
sigma_d2 = sum(d2)

 
splitedSize = round(len(c_sorted[:,2])/60)
d3_split = [d3[x:x+splitedSize] for x in range(0, len(d3), splitedSize)]
d2_split = [d2[x:x+splitedSize] for x in range(0, len(d2), splitedSize)]
d_avgsplit = [c_sorted[:,2][x:x+splitedSize] for x in range(0, len(c_sorted[:,2]), splitedSize)]
c_shortx  = [c_sorted[:,0][x:x+splitedSize] for x in range(0, len(c_sorted[:,0]), splitedSize)]
c_shorty  = [c_sorted[:,1][x:x+splitedSize] for x in range(0, len(c_sorted[:,1]), splitedSize)]

# %%
plt.plot(c_sorted[:,0],c_sorted[:,1], 'o')

# %%
d32=[];c_avgx =[];c_avgy =[];d_avg =[]

for i in range(0, len(c_shortx)):
    d32.append(sum(d3_split[i])/sum(d2_split[i]))
    c_avgx.append(sum(c_shortx[i])/(len(c_shortx[i])))
    c_avgy.append(sum(c_shorty[i])/(len(c_shorty[i])))
    d_avg.append(sum(d_avgsplit[i])/(len(d_avgsplit[i])))

# %%
plt.plot(c_avgx,c_avgy, label='KH current work')
plt.plot(Wave_st_Traject_Case2.iloc[:,0]-0.0007625, Wave_st_Traject_Case2.iloc[:,1]-0.000343, '*',label='Standard Wave Liu et al.')
# Traject_Exp_Case2.iloc[:,0] = Traject_Exp_Case2.iloc[:,0].astype(float)
plt.plot(Wave_Traject_Case2.iloc[:,0]-0.0007625, Wave_Traject_Case2.iloc[:,1]-0.00002, '--',label='Wave Liu et al.')
plt.plot(Traject_Exp_Case2.iloc[:,0]-0.0007625, Traject_Exp_Case2.iloc[:,1]-0.00027, 'o',label='Experiment PDPA')
plt.legend()
plt.xlabel('Horizontal position of the droplets [m]')
plt.ylabel('Vertical position of the droplets [m]')
plt.xlim(-0.0047625, 0.0057625)
# Out:
# (-0.0047625, 0.0057625)

# %%
plt.plot(c_avgx,c_avgy, label='KH current work')
plt.plot(TAB_Traject_Case4.iloc[:,0]-0.0007625, TAB_Traject_Case4.iloc[:,1], '--',label='TAB Liu et al.')
# plt.plot(Wave_Traject_Case4.iloc[:,0]-0.0007625,Wave_Traject_Case4.iloc[:,1], '--', label='Wave Liu et al.')
plt.plot(Traject_Exp_Case4.iloc[:,0]-0.0007625, Traject_Exp_Case4.iloc[:,1], 'o',label='Experiment')
plt.legend()
plt.xlabel('Horizontal position of the droplets [m]')
plt.ylabel('Vertical position of the droplets [m]')
plt.xlim(-0.0047625, 0)
plt.ylim(0.042, 0.0057625)
# Out:
# (0.042, 0.0057625)

# %%
plt.plot(c_avgx,d_avg, label='KH_Stijn')
plt.plot(data_Wave.iloc[:,0]-0.0007625, data_Wave.iloc[:, 1], '--', label='Wave')
plt.plot(data_TAB.iloc[:,0]-0.0007625, data_TAB.iloc[:, 1], '--', label='TAB')
plt.plot(data_PDPA.iloc[:,0]-0.0007625, data_PDPA.iloc[:,1], 'ko', label='PDPA')
plt.xlabel('Horizontal position of the droplets [m]')
plt.ylabel('Average droplet diameter [m]')
plt.title('Average droplet diameter over the horizontal penetration distance')
plt.legend()
plt.xlim(-0.0047625,0.006)
# Out:
# (-0.0047625, 0.006)

# %%
plt.plot(c_avgx,d32, label='KH current work')
# plt.plot(data_Wave.iloc[:,0]-0.0007625, data_Wave.iloc[:, 1], '--', label='Wave Liu et al.')
plt.plot(data_TAB.iloc[:,0]-0.0007625, data_TAB.iloc[:, 1], '--', label='TAB Liu et al.')
plt.plot(data_PDPA.iloc[:,0]-0.0007625, data_PDPA.iloc[:,1], 'ko', label='PDPA Measurement')
plt.xlabel('Horizontal position of the droplets [m]')
plt.ylabel('Sauter Mean Diameter [m]')
plt.legend()
plt.xlim(-0.0047625,0.0057625)
# Out:
# (-0.0047625, 0.0057625)

# %%
plt.plot(c_avgx,d32, label='KH current work')
plt.plot(TAB_Case3.iloc[:,0]-0.0007625,TAB_Case3.iloc[:,1], '--', label='TAB Liu et al.')
# plt.plot(KH_Case3.iloc[:,0]-0.0007625,KH_Case3.iloc[:,1], '--', label='Wave Liu et al.')
plt.plot(PDPA_Case3.iloc[:,0]-0.0007625,PDPA_Case3.iloc[:,1], 'ko', label='PDPA Measurement')
plt.legend()
plt.xlabel('Horizontal position of the droplets [m]')
plt.ylabel('Sauter Mean Diameter [m]')
plt.xlim(-0.0047625,0.0057625)
# Out:
# (-0.0047625, 0.0057625)

# %%
# plt.plot(c_avgx,d_avg, label='KH current work')
plt.plot(c_sorted[:,0],c_sorted[:,2],label='KH current work')
plt.plot(data_C4_SingleD.iloc[:,0]-0.0007625, data_C4_SingleD.iloc[:, 1], '--', label='Wave Liu et al.')
# plt.plot(c_sorted[:,0],c_sorted[:,2], label='Simulation openFoam')
plt.xlim(-0.0047325,0.00)
plt.legend()
plt.xlabel('Horizontal penetration distance [m]')
plt.ylabel('Droplet diameter [m]')
# Out:
# Text(0, 0.5, 'Droplet diameter [m]')

# %%
plt.plot(c_sorted[:,0],c_sorted[:,2])
