# %%
import os
import glob
import sys
import vtk

import pandas as pd    
import numpy as np
import matplotlib.pyplot as plt
from vtk.util.numpy_support import vtk_to_numpy

# %%
#Include depicted data...
#Case 2 -------------------------- Diameter import
data_Wave= pd.read_csv("./Case_Liu/Wave_Case2.csv", header=None) # Wave_Case2.csv
data_TAB= pd.read_csv("./Case_Liu/TAB_Case2.csv", header=None) # TAB_Case2.csv
data_PDPA= pd.read_csv("./Case_Liu/PDPA_Case2.csv", header=None) # PDPA_Case2.csv

#Case 3 -------------------------- Diameter import
TAB_Case3= pd.read_csv("./Case_Liu/TAB_Case3.csv", header=None) # TAB_Case3.csv
KH_Case3= pd.read_csv("./Case_Liu/Wave_Case3.csv", header=None) # SMD_KH_Case3Experiment.csv
PDPA_Case3= pd.read_csv("./Case_Liu/PDPA_Case3.csv", header=None) # PDPA_Case3.csv

#Case 4 -------------------------- Single droplet breakup
data_C4_SingleD= pd.read_csv("./Case_Liu/Case_4_Single_D.csv", header=None) # Case_4_Single_D.csv
data_C4_SingleRe= pd.read_csv("./Case_Liu/Case4_Single_Re.csv", header=None) # Case4_Single_Re.csv

#Case 2 ------------------------ Trajectory import
TAB_Traject_Case2= pd.read_csv("./Case_Liu/Trajectories/Trajectory_TAB_Case2.csv", header=None) # Trajectory_TAB_Case2.csv
Wave_Traject_Case2= pd.read_csv("./Case_Liu/Trajectories/Trajectory_Wave_Case2.csv", header=None) # Trajectory_Wave_Case2.csv
Wave_st_Traject_Case2= pd.read_csv("./Case_Liu/Trajectories/Trajectory_Wave_Case2-standard.csv", header=None) # Trajectory_Wave_Case2.csv
Traject_Exp_Case2= pd.read_csv("./Case_Liu/Trajectories/Trajectory_Experiment_Case2.csv", header=None) # Trajectory_Experiment_Case2.csv

#Case 4 -------------------------- Trajectory import
TAB_Traject_Case4= pd.read_csv("./Case_Liu/Trajectories/TAB_Case4_amp0_2.csv", header=None) # TAB_Traject_Case4.csv
Wave_Traject_Case4= pd.read_csv("./Case_Liu/Trajectories/Trajectory_Wave_Case4.csv", header=None) # Trajectory_Wave_Case4.csv
Traject_Exp_Case4= pd.read_csv("./Case_Liu/Trajectories/Trajectory_Experiment_Case4.csv", header=None) # Trajectory_Experiment_Case4.csv

# %%
fdir = "./Case4/TAB/lagrangian/sprayCloud" # sprayCloud file of Case 
#check if directory exists
if not os.path.exists(fdir):
    print('Error: Path does not exist:', fdir)
    sys.exit()

# %%
# create reader
reader = vtk.vtkXMLPolyDataReader() # a class that reads an XML-based VTK file format that contains polygonal data
# -------------------------------------------------------------------
points =[]
point_data=[]
point_d = []
point_d0 = [];
#loop over all vtp files
for fname in sorted(glob.glob(os.path.join(fdir, '*.vtp'))): # fdir in where vtp files stored 
    print('Reading:', fname)
    reader.SetFileName(fname)
    reader.Update()

    # print the arrays
    data = (reader.GetOutput())
    point_data.append(data.GetPointData())
    point_d.append(vtk_to_numpy((data.GetPointData()).GetArray('d')))
    point_d0.append(vtk_to_numpy((data.GetPointData()).GetArray('d0')))    
    points.append((vtk_to_numpy(data.GetPoints().GetData())))
# Out:
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5107.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5122.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5137.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5152.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5167.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5182.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5197.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5212.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5227.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5242.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5257.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5272.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5287.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5302.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5317.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5332.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5347.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5362.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5377.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5392.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5407.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5422.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5437.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5452.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5467.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5482.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5497.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5512.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5527.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5542.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5557.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5572.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5587.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5602.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5617.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5633.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5649.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5665.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5681.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5696.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5711.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5726.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5741.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5756.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5771.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5786.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5801.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5816.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5831.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5846.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5861.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5876.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5891.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5906.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5921.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5936.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5951.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5966.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5981.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_5996.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6011.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6026.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6041.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6056.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6071.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6086.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6101.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6116.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6131.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6146.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6161.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6176.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6191.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6206.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6221.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6236.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6251.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6266.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6281.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6296.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6311.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6326.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6341.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6356.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6371.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6386.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6401.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6416.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6431.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6446.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6461.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6476.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6491.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6506.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6521.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6536.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6551.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6566.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6581.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6596.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6611.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6626.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6641.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6656.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6671.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6686.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6701.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6716.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6731.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6746.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6761.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6776.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6791.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6806.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6821.vtp
# Reading: ./Case4/TAB/lagrangian/sprayCloud/sprayCloud_6836.vtp

# %%
d0 =[];
for i in range(0, len(points)):
    d0.append(np.array(point_d0[i]))
d0=np.concatenate(d0,axis=0)

# %%
px=[]
py=[]
pz=[]
for i in range(0, len(points)):
    px.append(np.array(points[i][:,0]))
    py.append(np.array(points[i][:,1]))
    pz.append(np.array(points[i][:,2]))

# %%
diameter =[]
Reyn =[]
diameter0=[]
for i in range(0, len(points)):
    diameter.append(np.array(point_d[i]))
#     Reyn.append(np.array(Re[i]))
    diameter0.append(np.array(d0[i]))

# %%
diameter_total = np.concatenate( diameter, axis=0 )
px_total = np.concatenate( px, axis=0 )
py_total = np.concatenate( py, axis=0 )
pz_total = np.concatenate( pz, axis=0 )

c = np.column_stack((py_total, pz_total,diameter_total))
c_sorted = c[np.argsort(c[:, 0])]

# %%
plt.plot(c_sorted[:,0]+0.00572,c_sorted[:,1], 'o')
plt.xlabel('Horizontal position of the droplets')
plt.ylabel('Vertical position of the droplets')
plt.title('All position data from the simulation sorted over the horizontal position')
plt.xlim(0,0.008)
# Out:
# (0.0, 0.008)

# %%
plt.plot(c_sorted[:,0],c_sorted[:,2])
plt.xlabel('Horizontal position of the droplets [m]')
plt.ylabel('Droplet diameter [m]')
plt.title('Droplet diameter over the horizontal penetration distance')
plt.xlim(-0.0072,0.0057625)
# Out:
# (-0.0072, 0.0057625)

# %%
# Computing the Sauter mean diameter for a specific amount of segments
d3 = pow(c_sorted[:,2],3)
sigma_d3 = sum(d3)
d2 = pow(c_sorted[:,2],2)
sigma_d2 = sum(d2)

 
splitedSize = round(len(c_sorted[:,2])/60)
d3_split = [d3[x:x+splitedSize] for x in range(0, len(d3), splitedSize)]
d2_split = [d2[x:x+splitedSize] for x in range(0, len(d2), splitedSize)]
d_avgsplit = [c_sorted[:,2][x:x+splitedSize] for x in range(0, len(c_sorted[:,2]), splitedSize)]
c_shortx  = [c_sorted[:,0][x:x+splitedSize] for x in range(0, len(c_sorted[:,0]), splitedSize)]
c_shorty  = [c_sorted[:,1][x:x+splitedSize] for x in range(0, len(c_sorted[:,1]), splitedSize)]

# %%
plt.plot(c_sorted[:,0],c_sorted[:,1], 'o')

# %%
d32=[];c_avgx =[];c_avgy =[];d_avg =[]

for i in range(0, len(c_shortx)):
    d32.append(sum(d3_split[i])/sum(d2_split[i]))
    c_avgx.append(sum(c_shortx[i])/(len(c_shortx[i])))
    c_avgy.append(sum(c_shorty[i])/(len(c_shorty[i])))
    d_avg.append(sum(d_avgsplit[i])/(len(d_avgsplit[i])))

# %%
plt.plot(c_avgx,c_avgy, label='KH current work')
plt.plot(Wave_st_Traject_Case2.iloc[:,0]-0.0007625, Wave_st_Traject_Case2.iloc[:,1]-0.000343, '*',label='Standard Wave Liu et al.')
# Traject_Exp_Case2.iloc[:,0] = Traject_Exp_Case2.iloc[:,0].astype(float)
plt.plot(Wave_Traject_Case2.iloc[:,0]-0.0007625, Wave_Traject_Case2.iloc[:,1]-0.00002, '--',label='Wave Liu et al.')
plt.plot(Traject_Exp_Case2.iloc[:,0]-0.0007625, Traject_Exp_Case2.iloc[:,1]-0.00027, 'o',label='Experiment PDPA')
plt.legend()
plt.xlabel('Horizontal position of the droplets [m]')
plt.ylabel('Vertical position of the droplets [m]')
plt.xlim(-0.0047625, 0.0057625)
# Out:
# (-0.0047625, 0.0057625)

# %%
plt.plot(c_avgx,c_avgy, label='TAB_case4 current work')
plt.plot(TAB_Traject_Case4.iloc[:,0]-0.0007625, TAB_Traject_Case4.iloc[:,1], '--',label='TAB Liu et al.')
#plt.plot(Wave_Traject_Case4.iloc[:,0]-0.0007625,Wave_Traject_Case4.iloc[:,1], '--', label='Wave Liu et al.')
plt.plot(Traject_Exp_Case4.iloc[:,0]-0.0007625, Traject_Exp_Case4.iloc[:,1], 'o',label='Experiment')
plt.legend()
plt.xlabel('Horizontal position of the droplets [m]')
plt.ylabel('Vertical position of the droplets [m]')
plt.xlim(-0.0047625, -0.0006)
plt.ylim(0.045, 0.056)
# Out:
# (0.045, 0.056)

# %%
plt.plot(c_avgx,d_avg, label='KH current work')
plt.plot(data_Wave.iloc[:,0]-0.0007625, data_Wave.iloc[:, 1], '--', label='Wave')
plt.plot(data_TAB.iloc[:,0]-0.0007625, data_TAB.iloc[:, 1], '--', label='TAB')
plt.plot(data_PDPA.iloc[:,0]-0.0007625, data_PDPA.iloc[:,1], 'ko', label='PDPA')
plt.xlabel('Horizontal position of the droplets [m]')
plt.ylabel('Average droplet diameter [m]')
plt.title('Average droplet diameter over the horizontal penetration distance')
plt.legend()
plt.xlim(-0.0047625,0.006)
# Out:
# (-0.0047625, 0.006)

# %%
plt.plot(c_avgx,d32, label='KH current work')
# plt.plot(data_Wave.iloc[:,0]-0.0007625, data_Wave.iloc[:, 1], '--', label='Wave Liu et al.')
plt.plot(data_TAB.iloc[:,0]-0.0007625, data_TAB.iloc[:, 1], '--', label='TAB Liu et al.')
plt.plot(data_PDPA.iloc[:,0]-0.0007625, data_PDPA.iloc[:,1], 'ko', label='PDPA Measurement')
plt.xlabel('Horizontal position of the droplets [m]')
plt.ylabel('Sauter Mean Diameter [m]')
plt.legend()
plt.xlim(-0.0047625,0.0057625)
# Out:
# (-0.0047625, 0.0057625)

# %%
plt.plot(c_avgx,d32, label='KH current work')
plt.plot(TAB_Case3.iloc[:,0]-0.0007625,TAB_Case3.iloc[:,1], '--', label='TAB Liu et al.')
# plt.plot(KH_Case3.iloc[:,0]-0.0007625,KH_Case3.iloc[:,1], '--', label='Wave Liu et al.')
plt.plot(PDPA_Case3.iloc[:,0]-0.0007625,PDPA_Case3.iloc[:,1], 'ko', label='PDPA Measurement')
plt.legend()
plt.xlabel('Horizontal position of the droplets [m]')
plt.ylabel('Sauter Mean Diameter [m]')
plt.xlim(-0.0047625,0.0057625)
# Out:
# (-0.0047625, 0.0057625)

# %%
# plt.plot(c_avgx,d_avg, label='KH current work')
plt.plot(c_sorted[:,0],c_sorted[:,2],label='KH current work')
plt.plot(data_C4_SingleD.iloc[:,0]-0.0007625, data_C4_SingleD.iloc[:, 1], '--', label='Wave Liu et al.')
# plt.plot(c_sorted[:,0],c_sorted[:,2], label='Simulation openFoam')
plt.xlim(-0.0047325,0.00)
plt.legend()
plt.xlabel('Horizontal penetration distance [m]')
plt.ylabel('Droplet diameter [m]')
# Out:
# Text(0, 0.5, 'Droplet diameter [m]')

# %%
plt.plot(c_sorted[:,0],c_sorted[:,2])
