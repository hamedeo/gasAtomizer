# %%
import os
import glob
import sys
import vtk

import pandas as pd    
import numpy as np
import matplotlib.pyplot as plt
from vtk.util.numpy_support import vtk_to_numpy

# %%
#Case 2 -------------------------- Diameter import
data_Wave= pd.read_csv("Simulation_Data\Case_Data\Wave_Case2.csv", header=None)
data_TAB= pd.read_csv("Simulation_Data\Case_Data\TAB_Case2.csv", header=None)

data_PDPA= pd.read_csv("Simulation_Data\Case_Data\PDPA_Case2.csv", header=None)

#Case 3 -------------------------- Diameter import
TAB_Case3= pd.read_csv("Simulation_Data\Case_Data\TAB_Case3.csv", header=None)
KH_Case3= pd.read_csv("Simulation_Data\Case_Data\SMD\SMD_KH_Case3Experiment.csv", header=None)
PDPA_Case3= pd.read_csv("Simulation_Data\Case_Data\PDPA_Case3.csv", header=None)

#Case 4 -------------------------- Single droplet breakup
data_C4_SingleD= pd.read_csv("Simulation_Data\Case_Data\Case_4_Single_D.csv", header=None)
data_C4_SingleRe= pd.read_csv("Simulation_Data\Case_Data\Case4_Single_Re.csv", header=None)

#Case 2 ------------------------ Trajectory import
TAB_Traject_Case2= pd.read_csv("Simulation_Data\Case_Data\Trajectories\TAB\Trajectory_TAB_Case2.csv", header=None)
Wave_Traject_Case2= pd.read_csv("Simulation_Data\Case_Data\Trajectories\Wave\Trajectory_Wave_Case2.csv", header=None)
Traject_Exp_Case2= pd.read_csv("Simulation_Data\Case_Data\Trajectories\TAB\Trajectory_Experiment_Case2.csv", header=None)

#Case 4 -------------------------- Trajectory import
TAB_Traject_Case4= pd.read_csv("Simulation_Data\Case_Data\Trajectories\TAB\TAB_Traject_Case4.csv", header=None)
Wave_Traject_Case4= pd.read_csv("Simulation_Data\Case_Data\Trajectories\Wave\Trajectory_Wave_Case4.csv", header=None)
Traject_Exp_Case4= pd.read_csv("Simulation_Data\Case_Data\Trajectories\TAB\Trajectory_Experiment_Case4.csv", header=None)

# %%
fdir = "Final_Simulations\Case3\We6\TAB\sprayCloud"
#check if directory exists
if not os.path.exists(fdir):
    print('Error: Path does not exist:', fdir)
    sys.exit()

# %%
# create reader
reader = vtk.vtkXMLPolyDataReader()
# -------------------------------------------------------------------
points =[]
point_data=[]
point_d = []
point_d0 = [];
#loop over all vtp files
for fname in sorted(glob.glob(os.path.join(fdir, '*.vtp'))):
    print('Reading:', fname)
    reader.SetFileName(fname)
    reader.Update()

    # print the arrays
    data = (reader.GetOutput())
    point_data.append(data.GetPointData())
    point_d.append(vtk_to_numpy((data.GetPointData()).GetArray('d')))
    point_d0.append(vtk_to_numpy((data.GetPointData()).GetArray('d0')))    
    points.append((vtk_to_numpy(data.GetPoints().GetData())))
# Out:
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_2686.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_2697.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_2708.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_2719.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_2730.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_2741.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_2752.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_2763.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_2774.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_2785.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_2796.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_2807.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_2818.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_2829.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_2840.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_2851.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_2862.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_2873.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_2884.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_2895.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_2906.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_2917.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_2928.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_2939.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_2950.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_2961.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_2972.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_2983.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_2994.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3005.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3016.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3027.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3038.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3049.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3060.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3071.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3082.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3093.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3104.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3115.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3126.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3137.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3148.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3159.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3170.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3181.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3192.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3203.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3214.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3225.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3236.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3247.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3258.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3269.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3280.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3291.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3302.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3313.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3324.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3335.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3346.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3357.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3368.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3379.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3390.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3401.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3412.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3423.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3434.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3445.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3456.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3467.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3478.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3489.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3500.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3511.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3522.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3533.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3544.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3555.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3566.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3577.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3588.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3599.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3610.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3621.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3632.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3643.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3654.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3665.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3676.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3687.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3698.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3709.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3720.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3731.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3742.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3753.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3764.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3775.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3786.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3797.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3808.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3819.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3830.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3841.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3852.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3863.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3874.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3885.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3896.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3907.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3918.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3929.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3940.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3951.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3962.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3973.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3984.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_3995.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4006.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4017.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4028.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4039.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4050.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4061.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4072.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4083.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4094.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4105.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4116.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4127.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4138.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4149.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4160.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4171.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4182.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4193.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4204.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4215.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4226.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4237.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4248.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4259.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4270.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4281.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4292.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4303.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4314.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4325.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4336.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4347.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4358.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4369.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4380.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4391.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4402.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4413.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4424.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4435.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4446.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4457.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4468.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4479.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4490.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4501.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4512.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4523.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4534.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4545.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4556.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4567.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4578.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4589.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4600.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4611.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4622.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4633.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4644.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4655.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4666.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4677.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4688.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4699.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4710.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4721.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4732.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4743.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4754.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4765.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4776.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4787.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4798.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4809.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4820.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4831.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4842.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4853.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4864.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4875.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4886.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4897.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4908.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4919.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4930.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4941.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4952.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4963.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4974.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4985.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_4996.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5007.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5018.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5029.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5040.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5051.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5062.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5073.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5084.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5095.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5106.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5117.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5129.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5141.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5153.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5165.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5177.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5189.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5201.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5213.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5225.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5237.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5249.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5261.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5273.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5285.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5297.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5309.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5321.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5333.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5345.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5357.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5368.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5379.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5390.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5401.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5412.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5423.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5434.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5445.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5456.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5467.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5478.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5489.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5500.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5511.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5522.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5533.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5544.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5555.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5566.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5577.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5588.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5600.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5612.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5624.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5635.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5646.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5657.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5668.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5679.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5690.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5701.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5712.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5723.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5734.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5746.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5758.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5770.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5782.vtp
# Reading: Final_Simulations\Case3\We6\TAB\sprayCloud\sprayCloud_5794.vtp

# %%
d0 =[];
for i in range(0, len(points)):
    d0.append(np.array(point_d0[i]))
d0=np.concatenate(d0,axis=0)

# %%
px=[]
py=[]
pz=[]
for i in range(0, len(points)):
    px.append(np.array(points[i][:,0]))
    py.append(np.array(points[i][:,1]))
    pz.append(np.array(points[i][:,2]))

# %%
diameter =[]
Reyn =[]
diameter0=[]
for i in range(0, len(points)):
    diameter.append(np.array(point_d[i]))
#     Reyn.append(np.array(Re[i]))
    diameter0.append(np.array(d0[i]))

# %%
diameter_total = np.concatenate( diameter, axis=0 )
px_total = np.concatenate( px, axis=0 )
py_total = np.concatenate( py, axis=0 )
pz_total = np.concatenate( pz, axis=0 )

c = np.column_stack((py_total, pz_total,diameter_total))
c_sorted = c[np.argsort(c[:, 0])]

# %%
plt.plot(c_sorted[:,0]+0.00572,c_sorted[:,1], 'o')
plt.xlabel('Horizontal position of the droplets')
plt.ylabel('Vertical position of the droplets')
plt.title('All position data from the simulation sorted over the horizontal position')
plt.xlim(0,0.008)
# Out:
# (0.0, 0.008)

# %%
plt.plot(c_sorted[:,0],c_sorted[:,2])
plt.xlabel('Horizontal position of the droplets [m]')
plt.ylabel('Droplet diameter [m]')
plt.title('Droplet diameter over the horizontal penetration distance')
plt.xlim(-0.0072,0.006)
# Out:
# (-0.0072, 0.006)

# %%
# Computing the Sauter mean diameter for a specific amount of segments
d3 = pow(c_sorted[:,2],3)
sigma_d3 = sum(d3)
d2 = pow(c_sorted[:,2],2)
sigma_d2 = sum(d2)

 
splitedSize = round(len(c_sorted[:,2])/60)
d3_split = [d3[x:x+splitedSize] for x in range(0, len(d3), splitedSize)]
d2_split = [d2[x:x+splitedSize] for x in range(0, len(d2), splitedSize)]
d_avgsplit = [c_sorted[:,2][x:x+splitedSize] for x in range(0, len(c_sorted[:,2]), splitedSize)]
c_shortx  = [c_sorted[:,0][x:x+splitedSize] for x in range(0, len(c_sorted[:,0]), splitedSize)]
c_shorty  = [c_sorted[:,1][x:x+splitedSize] for x in range(0, len(c_sorted[:,1]), splitedSize)]

# %%
plt.plot(c_sorted[:,0],c_sorted[:,1], 'o')

# %%
d32=[];c_avgx =[];c_avgy =[];d_avg =[]

for i in range(0, len(c_shortx)):
    d32.append(sum(d3_split[i])/sum(d2_split[i]))
    c_avgx.append(sum(c_shortx[i])/(len(c_shortx[i])))
    c_avgy.append(sum(c_shorty[i])/(len(c_shorty[i])))
    d_avg.append(sum(d_avgsplit[i])/(len(d_avgsplit[i])))

# %%
plt.plot(c_avgx,c_avgy, label='KH current work')
# plt.plot(((TAB_Traject_Case2.iloc[:,0])/1000), ((TAB_Traject_Case2.iloc[:,1]-2)/1e3), '--',label='TAB Liu et al.')
plt.plot(((Wave_Traject_Case2.iloc[:,0])/1000), (Wave_Traject_Case2.iloc[:,1]/1e3), '--',label='Wave Liu et al.')
plt.plot(((Traject_Exp_Case2.iloc[:,0])/1000), ((Traject_Exp_Case2.iloc[:,1]-2)/1e3), 'o',label='Experiment')
plt.legend()
plt.xlabel('Horizontal position of the droplets [m]')
plt.ylabel('Vertical position of the droplets [m]')
plt.xlim(-0.0047625, 0.006)
# Out:
# (-0.0047625, 0.006)

# %%
plt.plot((c_avgx),c_avgy, label='KH current work')
plt.plot(((TAB_Traject_Case4.iloc[:,0])-0.0047625), ((TAB_Traject_Case4.iloc[:,1])), '--',label='TAB Liu et al.')
# plt.plot((Wave_Traject_Case4.iloc[:,0])/1e3-0.0047625,(Wave_Traject_Case4.iloc[:,1])/1e3, '--', label='Wave Liu et al.')
plt.plot(((Traject_Exp_Case4.iloc[:,0])-0.0047625), ((Traject_Exp_Case4.iloc[:,1])), 'o',label='Experiment')
plt.legend()
plt.xlabel('Horizontal position of the droplets [m]')
plt.ylabel('Vertical position of the droplets [m]')
plt.xlim(-0.0047625, 0)
plt.ylim(0.042,0.057)
# Out:
# (0.042, 0.057)

# %%
plt.plot(c_avgx,d_avg, label='KH_Stijn')
plt.plot(((data_Wave.iloc[:, 0])/1000), (data_Wave.iloc[:, 1]/1e6), '--', label='Wave')
plt.plot(((data_TAB.iloc[:, 0])/1000), (data_TAB.iloc[:, 1]/1e6), '--', label='TAB')
plt.plot(((data_PDPA.iloc[:,0])/1000), (data_PDPA.iloc[:,1]/1e6), 'ko', label='PDPA')
plt.xlabel('Horizontal position of the droplets [m]')
plt.ylabel('Average droplet diameter [m]')
plt.title('Average droplet diameter over the horizontal penetration distance')
plt.legend()
plt.xlim(-0.0047625,0.006)
# Out:
# (-0.0047625, 0.006)

# %%
plt.plot(c_avgx,d32, label='KH current work')
# plt.plot(((data_Wave.iloc[:, 0])/1000), (data_Wave.iloc[:, 1]/1e6), '--', label='Wave Liu et al.')
plt.plot(((data_TAB.iloc[:, 0])/1000), (data_TAB.iloc[:, 1]/1e6), '--', label='TAB Liu et al.')
plt.plot(((data_PDPA.iloc[:,0])/1000), (data_PDPA.iloc[:,1]/1e6), 'ko', label='PDPA Measurement')
plt.xlabel('Horizontal position of the droplets [m]')
plt.ylabel('Sauter Mean Diameter [m]')
plt.legend()
plt.xlim(-0.0047625,0.006)
# Out:
# (-0.0047625, 0.006)

# %%
plt.plot(c_avgx,d32, label='KH current work')
plt.plot(TAB_Case3.iloc[:,0]/1e3-0.0047625,TAB_Case3.iloc[:,1]/1e6, '--', label='TAB Liu et al.')
# plt.plot(KH_Case3.iloc[:,0]/1e3-0.0047625,KH_Case3.iloc[:,1]/1e6, '--', label='Wave Liu et al.')
plt.plot(PDPA_Case3.iloc[:,0]/1e3-0.0047625,PDPA_Case3.iloc[:,1]/1e6, 'ko', label='PDPA Measurement')
plt.legend()
plt.xlabel('Horizontal position of the droplets [m]')
plt.ylabel('Sauter Mean Diameter [m]')
plt.xlim(-0.0047625,0.006)
# Out:
# (-0.0047625, 0.006)

# %%
# plt.plot(c_avgx,d_avg, label='KH current work')
plt.plot(c_sorted[:,0],c_sorted[:,2],label='KH current work')
plt.plot(((data_C4_SingleD.iloc[:, 0])/1e3), data_C4_SingleD.iloc[:, 1]/1e6, '--', label='Wave Liu et al.')
# plt.plot(c_sorted[:,0],c_sorted[:,2], label='Simulation openFoam')
plt.xlim(-0.0047325,0.00)
plt.legend()
plt.xlabel('Horizontal penetration distance [m]')
plt.ylabel('Droplet diameter [m]')
# Out:
# Text(0, 0.5, 'Droplet diameter [m]')

# %%
plt.plot(c_sorted[:,0],c_sorted[:,2])
